# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install snscrape

# %% [markdown]
# SNscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2020-12-22 until:2020-12-24').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2020-12-24 until:2020-12-26').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2020-12-28 until:2020-12-31').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2020-12-31 until:2021-01-02').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-04 until:2021-01-07').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-07 until:2021-01-09').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-11 until:2021-01-14').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-14 until:2021-01-16').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-18 until:2021-01-21').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-21 until:2021-01-23').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-25 until:2021-01-27').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-01-27 until:2021-01-30').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-01 until:2021-02-03').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-03 until:2021-02-06').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-08 until:2021-02-10').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-10 until:2021-02-13').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-15 until:2021-02-18').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-18 until:2021-02-20').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-22 until:2021-02-25').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-02-25 until:2021-02-27').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-03-01 until:2021-03-04').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-03-04 until:2021-03-06').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-03-08 until:2021-03-11').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-03-11 until:2021-03-13').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-03-15 until:2021-03-18').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-03-18 until:2021-03-20').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('PFE lang:en since:2021-03-20 until:2021-03-23').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_df
# Out:
#                      Datetime                                               Text
# 710 2021-01-21 00:00:45+00:00  Trump's Market Was So-So, Whichever Way You Cu...
# 709 2021-01-21 00:05:52+00:00  EU leaders convene amid vaccine delays, virus ...
# 708 2021-01-21 00:06:29+00:00  @spotgamma @StockBoardAsset #Israel: #Pfizerva...
# 707 2021-01-21 00:07:51+00:00  @ASeizew @Kevin_W81 Think $BNTX and $PFE may d...
# 706 2021-01-21 00:12:32+00:00  Wednesday #NYSE Top 100 Volume Leaders\n#Black...
# ..                        ...                                                ...
# 4   2021-03-22 23:09:10+00:00  @MSollender While directed at autoimmune/infla...
# 3   2021-03-22 23:13:02+00:00           AAPL*35\nPFE*145 https://t.co/g0t8FgImyq
# 2   2021-03-22 23:42:31+00:00  Besides a great newsletter, the Slack communit...
# 1   2021-03-22 23:45:57+00:00  $TGTX $ACIU $MSFT $AAPL $ZM $ZS $AMD $M $TSLA ...
# 0   2021-03-22 23:49:47+00:00                 @teramainia ... I'm not denying it
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
# !pip install emoji
# Out:
# ...
#      |████████████████████████████████| 133kB 5.3MB/s
# ...

# %%
import re
import emoji
tweets_df['Text'] = tweets_df['Text'].astype(str)

def cleaner(tweet):
    tweet = re.sub(r"(^|\W)\d+", "", tweet)# remove digits
    tweet = tweet.lower()
    if tweet[:2] == 'rt':
        tweet = re.sub(r'^.*?:', ':', tweet)
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI) #Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ")
    tweet = tweet.replace("RT ", "")
    tweet = re.sub(r'[^\w\s]','',tweet) #remove punctuation
    return tweet
tweets_df['processed_tweet'] = tweets_df['Text'].map(lambda x: cleaner(x))

# %%
tweets_df
# Out:
#                      Datetime  ...                                    processed_tweet
# 710 2021-01-21 00:00:45+00:00  ...  trumps market was soso whichever way you cut i...
# 709 2021-01-21 00:05:52+00:00  ...  eu leaders convene amid vaccine delays virus v...
# 708 2021-01-21 00:06:29+00:00  ...  israel pfizervaccine first dose less effective...
# 707 2021-01-21 00:07:51+00:00  ...   w81 think bntx and pfe may drop the acuitas a...
# 706 2021-01-21 00:12:32+00:00  ...  wednesday nyse top volume leaders blackberry l...
# ..                        ...  ...                                                ...
# 4   2021-03-22 23:09:10+00:00  ...  while directed at autoimmuneinflammation this ...
# 3   2021-03-22 23:13:02+00:00  ...                                           aapl pfe
# 2   2021-03-22 23:42:31+00:00  ...  besides a great newsletter the slack community...
# 1   2021-03-22 23:45:57+00:00  ...  tgtx aciu msft aapl zm zs amd m tsla crsp nflx...
# ...

# %%
tweets_df.to_csv('/content/drive/MyDrive/FA PROJECT 2021/Basic Regressors/PFE/60days_tweets.csv', index=False)
