# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install snscrape

# %% [markdown]
# SNscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2020-12-22 until:2020-12-24').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2020-12-24 until:2020-12-26').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2020-12-28 until:2020-12-31').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2020-12-31 until:2021-01-02').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-04 until:2021-01-07').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-07 until:2021-01-09').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-11 until:2021-01-14').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-14 until:2021-01-16').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-18 until:2021-01-21').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-21 until:2021-01-23').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-25 until:2021-01-27').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-01-27 until:2021-01-30').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-01 until:2021-02-03').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-03 until:2021-02-06').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-08 until:2021-02-10').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-10 until:2021-02-13').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-15 until:2021-02-18').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-18 until:2021-02-20').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-22 until:2021-02-25').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-02-25 until:2021-02-27').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-01 until:2021-03-04').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-04 until:2021-03-06').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-08 until:2021-03-11').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-11 until:2021-03-13').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-15 until:2021-03-18').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-18 until:2021-03-20').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-20 until:2021-03-23').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_df
# Out:
#                      Datetime                                               Text
# 261 2021-01-21 00:27:43+00:00  $NVAX look like it’s finna boom according to t...
# 260 2021-01-21 00:31:02+00:00  @AkremAk @InovioPharma man a company that does...
# 259 2021-01-21 01:27:00+00:00  @NateSilver538 @thehowie Agreed. Ultimately it...
# 258 2021-01-21 01:38:50+00:00  @AlexDelarge6553 @MentalHealthVR @Bill01234567...
# 257 2021-01-21 02:34:34+00:00  @RNAiAnalyst Slaoui has always protected the b...
# ..                        ...                                                ...
# 4   2021-03-22 22:58:52+00:00  $NVAX went from 4$ to 300$ under 2 years (84x)...
# 3   2021-03-22 23:26:37+00:00  Join Robinhood with my link and we'll both get...
# 2   2021-03-22 23:28:13+00:00  What Happened Today in the US Stock Market?\n\...
# 1   2021-03-22 23:45:57+00:00  $TGTX $ACIU $MSFT $AAPL $ZM $ZS $AMD $M $TSLA ...
# 0   2021-03-22 23:46:36+00:00  STOCK, OPTIONS updates, alerts Free chatroom\n...
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
# !pip install emoji
# Out:
# ...
#      |████████████████████████████████| 133kB 5.3MB/s
# ...

# %%
import re
import emoji
tweets_df['Text'] = tweets_df['Text'].astype(str)

def cleaner(tweet):
    tweet = re.sub(r"(^|\W)\d+", "", tweet)# remove digits
    tweet = tweet.lower()
    if tweet[:2] == 'rt':
        tweet = re.sub(r'^.*?:', ':', tweet)
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI) #Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ")
    tweet = tweet.replace("RT ", "")
    tweet = re.sub(r'[^\w\s]','',tweet) #remove punctuation
    return tweet
tweets_df['processed_tweet'] = tweets_df['Text'].map(lambda x: cleaner(x))

# %%
tweets_df
# Out:
#                      Datetime  ...                                    processed_tweet
# 261 2021-01-21 00:27:43+00:00  ...  nvax look like its finna boom according to the...
# 260 2021-01-21 00:31:02+00:00  ...  man a company that doesnt have debt and even h...
# 259 2021-01-21 01:27:00+00:00  ...  agreed ultimately it all sort of comes togethe...
# 258 2021-01-21 01:38:50+00:00  ...  for all those paying close attention to rlftf ...
# 257 2021-01-21 02:34:34+00:00  ...  slaoui has always protected the big guns hes b...
# ..                        ...  ...                                                ...
# 4   2021-03-22 22:58:52+00:00  ...  nvax went from to under years x and some peopl...
# 3   2021-03-22 23:26:37+00:00  ...  join robinhood with my link and well both get ...
# 2   2021-03-22 23:28:13+00:00  ...  what happened today in the us stock market chw...
# 1   2021-03-22 23:45:57+00:00  ...  tgtx aciu msft aapl zm zs amd m tsla crsp nflx...
# ...

# %%
tweets_df.to_csv('/content/drive/MyDrive/FA PROJECT 2021/Basic Regressors/NVAX/60days_tweets.csv', index=False)
