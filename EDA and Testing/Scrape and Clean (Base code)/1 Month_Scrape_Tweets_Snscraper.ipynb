# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install snscrape

# %% [markdown]
# SNscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NVAX lang:en since:2021-03-20 until:2021-03-21').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2020-12-24 until:2020-12-26').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2020-12-28 until:2020-12-31').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2020-12-31 until:2021-01-02').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-04 until:2021-01-07').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-07 until:2021-01-09').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-11 until:2021-01-14').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-14 until:2021-01-16').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-18 until:2021-01-21').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-21 until:2021-01-23').get_items()):
    tweets_list.append([tweet.date, tweet.content])
   
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df[::-1]

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-25 until:2021-01-27').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-01-27 until:2021-01-30').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-01 until:2021-02-03').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-03 until:2021-02-06').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-08 until:2021-02-10').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-10 until:2021-02-13').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-15 until:2021-02-18').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-18 until:2021-02-20').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-22 until:2021-02-25').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-02-25 until:2021-02-27').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-03-01 until:2021-03-04').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-03-04 until:2021-03-06').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-03-08 until:2021-03-11').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-03-11 until:2021-03-13').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-03-15 until:2021-03-18').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_list = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('SIGL lang:en since:2021-03-18 until:2021-03-20').get_items()):
    tweets_list.append([tweet.date, tweet.content])
    
tweets_df1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text'])
tweets_df = tweets_df.append(tweets_df1[::-1])

# %%
tweets_df
# Out:
#                        Datetime                                               Text
# 15128 2021-01-21 00:07:29+00:00  If you haven't signed up for https://t.co/ut4V...
# 15127 2021-01-21 00:08:09+00:00  Alright #fintwit if you were to make a 5 figur...
# 15126 2021-01-21 00:08:20+00:00            $GME 🚀 Ready to load up on more shares.
# 15125 2021-01-21 00:10:38+00:00  Slime For My [Official Music Video] https://t....
# 15124 2021-01-21 00:12:32+00:00  Wednesday #NYSE Top 100 Volume Leaders\n#Black...
# ...                         ...                                                ...
# 4     2021-03-19 23:58:22+00:00  @onlytruejosh @stevenson3529 @YoruBadG Why are...
# 3     2021-03-19 23:58:45+00:00  $HOFV might be the next $GME https://t.co/q2y4...
# 2     2021-03-19 23:59:10+00:00       @SpaceX @elonmusk we need a GME TWEET PLEASE
# 1     2021-03-19 23:59:41+00:00  @CNBC why don’t you talk about the manipulatio...
# ...

# %%
import pandas as pd
import numpy as np

# %%
# !pip install emoji

# %%
import re
import emoji
tweets_df['Text'] = tweets_df['Text'].astype(str)

def cleaner(tweet):
    tweet = re.sub(r"(^|\W)\d+", "", tweet)# remove digits
    tweet = tweet.lower()
    if tweet[:2] == 'rt':
        tweet = re.sub(r'^.*?:', ':', tweet)
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI) #Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ")
    tweet = tweet.replace("RT ", "")
    tweet = re.sub(r'[^\w\s]','',tweet) #remove punctuation
    return tweet
tweets_df['processed_tweet'] = tweets_df['Text'].map(lambda x: cleaner(x))

# %%
tweets_df
# Out:
#                     Datetime  ...                                    processed_tweet
# 56 2021-03-20 00:16:10+00:00  ...  join robinhood with my link and well both get ...
# 55 2021-03-20 00:21:29+00:00  ...  and i thought i woke up to madness yesterday  ...
# 54 2021-03-20 00:55:51+00:00  ...  look like legit traders include this chat and ...
# 53 2021-03-20 01:03:53+00:00  ...  novavax inc current quarter revenue growth yoy...
# 52 2021-03-20 01:06:23+00:00  ...  join robinhood with my link and well both get ...
# 51 2021-03-20 01:40:09+00:00  ...                        buy nvax and thank me later
# 50 2021-03-20 02:16:03+00:00  ...                             doge aapl tlry f nvax
# 49 2021-03-20 03:20:15+00:00  ...  should have bought  buy novavax nvax  their ef...
# 48 2021-03-20 03:53:40+00:00  ...  they offered me the effective vaccine pass ill...
# 47 2021-03-20 07:16:14+00:00  ...  join robinhood with my link and well both get ...
# ...

# %%
tweets_df.to_csv('/content/drive/MyDrive/FA PROJECT 2021/nvax_tweets_20mar.csv', index=False)
